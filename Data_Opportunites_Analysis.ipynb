# %% [markdown]
# <a href="https://colab.research.google.com/github/MINAADELMARKOS/Data_Opportunites_Analysis/blob/main/Data_Opportunites_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Imoort Libraries**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.figure_factory as ff
import plotly.io as pio
import plotly.graph_objects as go

# %%
import plotly.io as pio
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly_white'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
pio.templates.default = 'plotly_white'

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Epslion Project before midproject/Data Analyst Project/DataAnalyst.csv')

# %% [markdown]
# # **Explatory Data Analyst**

# %%
df.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
df.columns[0]
# Out:
# 'Unnamed: 0'

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
str_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in str_columns:
  df[col] = df[col].str.lower().str.replace(' ','_')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  data_analyst,_center_on_immigration_and_justic...
# 1                               quality_data_analyst
# 2  senior_data_analyst,_insights_&_analytics_team...
# 3                                       data_analyst
# 4                             reporting_data_analyst
#
#               Salary Estimate  \
# 0  $37k-$66k_(glassdoor_est.)
# 1  $37k-$66k_(glassdoor_est.)
# 2  $37k-$66k_(glassdoor_est.)
# 3  $37k-$66k_(glassdoor_est.)
# 4  $37k-$66k_(glassdoor_est.)
#
#                                      Job Description  Rating  \
# 0  are_you_eager_to_roll_up_your_sleeves_and_harn...     3.2
# 1  overview\n\nprovides_analytical_and_technical_...     3.8
# 2  we’re_looking_for_a_senior_data_analyst_who_ha...     3.4
# 3  requisition_numberrr-0001939\nremote:yes\nwe_c...     4.1
# 4  about_fanduel_group\n\nfanduel_group_is_a_worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           vera_institute_of_justice\n3.2  new_york,_ny  new_york,_ny
# 1  visiting_nurse_service_of_new_york\n3.8  new_york,_ny  new_york,_ny
# 2                         squarespace\n3.4  new_york,_ny  new_york,_ny
# 3                            celerity\n4.1  new_york,_ny    mclean,_va
# 4                             fanduel\n3.9  new_york,_ny  new_york,_ny
#
#                      Size  Founded               Type of ownership  \
# 0    201_to_500_employees     1961          nonprofit_organization
# 1        10000+_employees     1893          nonprofit_organization
# 2  1001_to_5000_employees     2003               company_-_private
# 3    201_to_500_employees     2002  subsidiary_or_business_segment
# 4   501_to_1000_employees     2009               company_-_private
#
#                            Industry                            Sector  \
# 0                 social_assistance                        non-profit
# 1  health_care_services_&_hospitals                       health_care
# 2                          internet            information_technology
# 3                       it_services            information_technology
# 4               sports_&_recreation  arts,_entertainment_&_recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100_to_$500_million_(usd)          -1       true
# 1      $2_to_$5_billion_(usd)          -1         -1
# 2    unknown_/_non-applicable     godaddy         -1
# 3   $50_to_$100_million_(usd)          -1         -1
# 4  $100_to_$500_million_(usd)  draftkings       true

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2253 non-null   object
#  1   Salary Estimate    2253 non-null   object
#  2   Job Description    2253 non-null   object
#  3   Rating             2253 non-null   float64
#  4   Company Name       2252 non-null   object
#  5   Location           2253 non-null   object
#  6   Headquarters       2253 non-null   object
#  7   Size               2253 non-null   object
#  8   Founded            2253 non-null   int64
#  9   Type of ownership  2253 non-null   object
#  10  Industry           2253 non-null   object
#  11  Sector             2253 non-null   object
#  12  Revenue            2253 non-null   object
#  13  Competitors        2253 non-null   object
#  14  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 264.1+ KB

# %%
df.isna().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
df.describe()
# Out:
#             Rating      Founded
# count  2253.000000  2253.000000
# mean      3.160630  1398.522858
# std       1.665228   901.929251
# min      -1.000000    -1.000000
# 25%       3.100000    -1.000000
# 50%       3.600000  1979.000000
# 75%       4.000000  2002.000000
# max       5.000000  2019.000000

# %%
df.replace(-1,np.nan,inplace=True)

# %%
df.describe()
# Out:
#             Rating      Founded
# count  1981.000000  1593.000000
# mean      3.731903  1978.362837
# std       0.670332    47.822289
# min       1.000000  1682.000000
# 25%       3.300000  1970.000000
# 50%       3.700000  1997.000000
# 75%       4.100000  2006.000000
# max       5.000000  2019.000000

# %%
df.isna().sum()
# Out:
# Job Title              0
# Salary Estimate        0
# Job Description        0
# Rating               272
# Company Name           1
# Location               0
# Headquarters           0
# Size                   0
# Founded              660
# Type of ownership      0
# Industry               0
# Sector                 0
# Revenue                0
# Competitors            0
# Easy Apply             0
# dtype: int64

# %%
df.describe(include='O')
# Out:
#            Job Title             Salary Estimate  \
# count           2253                        2253
# unique          1257                          90
# top     data_analyst  $42k-$76k_(glassdoor_est.)
# freq             411                          57
#
#                                           Job Description  \
# count                                                2253
# unique                                               2252
# top     job_description\ninterpret_data,_analyze_resul...
# freq                                                    2
#
#                                  Company Name      Location  Headquarters  \
# count                                    2252          2253          2253
# unique                                   1511           253           483
# top     staffigo_technical_services,_llc\n5.0  new_york,_ny  new_york,_ny
# freq                                       58           310           206
#
#                        Size  Type of ownership Industry  \
# count                  2253               2253     2253
# unique                    9                 15       89
# top     51_to_200_employees  company_-_private       -1
# freq                    421               1273      353
#
#                         Sector                   Revenue Competitors  \
# count                     2253                      2253        2253
# unique                      25                        14         291
# top     information_technology  unknown_/_non-applicable          -1
# freq                       570                       615        1732
#
#        Easy Apply
# count        2253
# unique          2
# top            -1
# freq         2173

# %%
df.replace('-1',np.nan,inplace=True)

# %%
df.describe(include='O')
# Out:
#            Job Title             Salary Estimate  \
# count           2253                        2252
# unique          1257                          89
# top     data_analyst  $42k-$76k_(glassdoor_est.)
# freq             411                          57
#
#                                           Job Description  \
# count                                                2253
# unique                                               2252
# top     job_description\ninterpret_data,_analyze_resul...
# freq                                                    2
#
#                                  Company Name      Location  Headquarters  \
# count                                    2252          2253          2081
# unique                                   1511           253           482
# top     staffigo_technical_services,_llc\n5.0  new_york,_ny  new_york,_ny
# freq                                       58           310           206
#
#                        Size  Type of ownership     Industry  \
# count                  2090               2090         1900
# unique                    8                 14           88
# top     51_to_200_employees  company_-_private  it_services
# freq                    421               1273          325
#
#                         Sector                   Revenue       Competitors  \
# count                     1900                      2090               521
# unique                      24                        13               290
# top     information_technology  unknown_/_non-applicable  adecco,_manpower
# freq                       570                       615                14
#
#        Easy Apply
# count          80
# unique          1
# top          true
# freq           80

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         1
# Job Description         0
# Rating                272
# Company Name            1
# Location                0
# Headquarters          172
# Size                  163
# Founded               660
# Type of ownership     163
# Industry              353
# Sector                353
# Revenue               163
# Competitors          1732
# Easy Apply           2173
# dtype: int64

# %% [markdown]
# # **Handeling Missing Data**

# %%
df['Easy Apply'].to_frame().head(6)
# Out:
#   Easy Apply
# 0       true
# 1        NaN
# 2        NaN
# 3        NaN
# 4       true
# 5        NaN

# %%
df['Easy Apply'].replace(np.nan,"apply on company website",inplace=True)

# %%
df['Easy Apply'].to_frame().head(6)
# Out:
#                  Easy Apply
# 0                      true
# 1  apply on company website
# 2  apply on company website
# 3  apply on company website
# 4                      true
# 5  apply on company website

# %%
df['Easy Apply'].value_counts()
# Out:
# apply on company website    2173
# true                          80
# Name: Easy Apply, dtype: int64

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         1
# Job Description         0
# Rating                272
# Company Name            1
# Location                0
# Headquarters          172
# Size                  163
# Founded               660
# Type of ownership     163
# Industry              353
# Sector                353
# Revenue               163
# Competitors          1732
# Easy Apply              0
# dtype: int64

# %%
df.dropna(subset=['Salary Estimate','Company Name'],inplace = True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                271
# Company Name            0
# Location                0
# Headquarters          171
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
px.histogram(df,x='Rating')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5bf105a9-a409-4127-a61d-e742d14b2036" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bf105a9-a409-4127-a61d-e742d14b2036")) {                    Plotly.newPlot(                        "5bf105a9-a409-4127-a61d-e742d14b2036",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Rating=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3.2,3.8,3.4,4.1,3.9,3.9,4.4,3.7,4.0,4.4,4.0,null,3.7,3.0,3.4,3.6,3.8,3.8,3.9,4.9,4.4,null,3.3,3.5,3.8,4.0,5.0,4.8,3.7,4.7,3.6,3.6,3.5,3.2,null,3.7,null,3.6,4.0,4.6,null,null,5.0,4.0,3.0,2.9,4.0,3.6,4.9,3.9,4.0,3.8,3.7,3.6,3.6,null,4.0,3.2,3.8,3.9,4.8,3.6,3.6,3.6,4.1,3.9,3.0,3.7,null,3.9,3.7,null,3.6,3.7,3.6,4.1,3.5,3.7,5.0,4.0,4.8,5.0,3.3,4.1,4.0,null,1.0,3.1,4.5,3.4,null,3.6,4.1,4.4,3.8,3.2,null,3.8,4.7,2.3,3.8,4.6,3.0,3.9,3.0,4.2,5.0,4.0,null,null,3.6,3.7,3.5,2.8,5.0,3.8,3.4,3.6,null,3.2,3.8,3.5,3.5,4.1,5.0,3.7,4.0,3.3,2.9,3.6,3.2,3.1,3.4,4.0,4.3,2.7,4.1,4.4,3.1,3.0,2.9,3.9,4.2,3.9,4.2,
_auto=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="45fe73b6-cf1d-46ae-ab7b-ef0962209d3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45fe73b6-cf1d-46ae-ab7b-ef0962209d3f")) {                    Plotly.newPlot(                        "45fe73b6-cf1d-46ae-ab7b-ef0962209d3f",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Rating","Founded"],"y":["Rating","Founded"],"z":[[1.0,0.18],[0.18,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"s ...

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                271
# Company Name            0
# Location                0
# Headquarters          171
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
df['Rating'].median()
# Out:
# 3.7

# %%
df['Rating'].fillna(df['Rating'].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# Headquarters          171
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
pd.pivot_table(df, values='Job Title', index=['Salary Estimate'],
                    columns=['Size'], aggfunc='count', fill_value=0)
# Out:
# Size                          10000+_employees  1001_to_5000_employees  \
# Salary Estimate
# $110k-$190k_(glassdoor_est.)                 3                       7
# $113k-$132k_(glassdoor_est.)                 4                       4
# $24k-$48k_(glassdoor_est.)                   7                       6
# $26k-$47k_(glassdoor_est.)                   3                       2
# $27k-$52k_(glassdoor_est.)                   9                       4
# ...                                        ...                     ...
# $89k-$151k_(glassdoor_est.)                  5                       4
# $93k-$159k_(glassdoor_est.)                  2                       5
# $97k-$129k_(glassdoor_est.)                  6                       3
# $98k-$114k_(glassdoor_est.)                  5                       3
# $99k-$178k_(glassdoor_est.)                  3                       4
#
# Size                          1_to_50_employees  201_to_500_employees  \
# Salary Estimate
# $110k-$190k_(glassdoor_est.)                  3                     3
# $113k-$132k_(glassdoor_est.)                  4                     3
# $24k-$48k_(glassdoor_est.)                    4                     3
# $26k-$47k_(glassdoor_est.)                    4                     1
# $27k-$52k_(glassdoor_est.)                    4                     2
# ...                                         ...                   ...
# $89k-$151k_(glassdoor_est.)                   4                     4
# $93k-$159k_(glassdoor_est.)                   3                     6
# $97k-$129k_(glassdoor_est.)                   6                     3
# $98k-$114k_(glassdoor_est.)                   5                     3
# $99k-$178k_(glassdoor_est.)                   4                     4
#
# Size                          5001_to_10000_employees  501_to_1000_employees  \
# Salary Estimate
# $110k-$190k_(glassdoor_est.)                        1                      4
# $113k-$132k_(glassdoor_est.)                        3                      3
# $24k-$48k_(glassdoor_est.)                          3                      3
# $26k-$47k_(glassdoor_est.)                          1                      6
# $27k-$52k_(glassdoor_est.)                          2                      5
# ...                                               ...                    ...
# $89k-$151k_(glassdoor_est.)                         2                      2
# $93k-$159k_(glassdoor_est.)                         1                      3
# $97k-$129k_(glassdoor_est.)                         2                      1
# $98k-$114k_(glassdoor_est.)                         0                      6
# $99k-$178k_(glassdoor_est.)                         1                      3
#
# Size                          51_to_200_employees  unknown
# Salary Estimate
# $110k-$190k_(glassdoor_est.)                    6        0
# $113k-$132k_(glassdoor_est.)                    4        1
# $24k-$48k_(glassdoor_est.)                      3        0
# $26k-$47k_(glassdoor_est.)                      9        0
# $27k-$52k_(glassdoor_est.)                      3        0
# ...                                           ...      ...
# $89k-$151k_(glassdoor_est.)                     5        0
# $93k-$159k_(glassdoor_est.)                     5        0
# $97k-$129k_(glassdoor_est.)                     5        1
# $98k-$114k_(glassdoor_est.)                     5        1
# $99k-$178k_(glassdoor_est.)                     6        1
#
# [88 rows x 8 columns]

# %%
df[df['Headquarters'].isna()]
# Out:
#                                               Job Title  \
# 11                                         data_analyst
# 34                                 data_analyst_(games)
# 55                               data_reporting_analyst
# 68                                 data_science_analyst
# 90                                         data_analyst
# ...                                                 ...
# 2200                                       data_analyst
# 2202                             financial_data_analyst
# 2239                       senior_contract_data_analyst
# 2246  technical_business_analyst_(sql,_data_analytic...
# 2250  technical_business_analyst_(sql,_data_analytic...
#
#                   Salary Estimate  \
# 11     $37k-$66k_(glassdoor_est.)
# 34     $46k-$87k_(glassdoor_est.)
# 55     $46k-$87k_(glassdoor_est.)
# 68     $51k-$88k_(glassdoor_est.)
# 90     $51k-$87k_(glassdoor_est.)
# ...                           ...
# 2200   $49k-$91k_(glassdoor_est.)
# 2202   $49k-$91k_(glassdoor_est.)
# 2239  $78k-$104k_(glassdoor_est.)
# 2246  $78k-$104k_(glassdoor_est.)
# 2250  $78k-$104k_(glassdoor_est.)
#
#                                         Job Description  Rating  \
# 11    bulbhead_is_currently_seeking_a_data_analyst_t...     3.7
# 34    carry1st_is_the_leading_mobile_game_publisher_...     3.7
# 55    overviewthe_data_analyst_is_a_new_position_in_...     3.7
# 68    job_details\n\nlevel\n\nexperienced\n\njob_loc...     3.7
# 90    nyu_grossman_school_of_medicine_is_one_of_the_...     3.7
# ...                                                 ...     ...
# 2200  role_data_analyst_duration12+_months_location_...     3.7
# 2202  position:financial_data_analystjob_description...     3.7
# 2239  overviewamyx_is_seeking_to_hire_a_senior_contr...     3.7
# 2246  spiceorb_is_looking_for_technical_business_ana...     3.7
# 2250  title:_technical_business_analyst_(sql,_data_a...     3.7
#
#                                            Company Name        Location  \
# 11                                             bulbhead   fairfield,_nj
# 34                                             carry1st    new_york,_ny
# 55                                       nadap_nys_inc.    new_york,_ny
# 68    greater_new_york_mutual_insurance_companies_(gny)    new_york,_ny
# 90                           nyu_langone_medical_center    new_york,_ny
# ...                                                 ...             ...
# 2200          techaspect_solutions,_inc._dba_ta_digital  centennial,_co
# 2202        black_knight_financial_technology_solutions      denver,_co
# 2239                                        amyx,_iinc.      aurora,_co
# 2246                                           spiceorb      denver,_co
# 2250                                           spiceorb      denver,_co
#
#      Headquarters               Size  Founded  Type of ownership Industry  \
# 11            NaN  1_to_50_employees      NaN  company_-_private      NaN
# 34            NaN                NaN      NaN                NaN      NaN
# 55            NaN                NaN      NaN                NaN      NaN
# 68            NaN                NaN      NaN                NaN      NaN
# 90            NaN                NaN      NaN                NaN      NaN
# ...           ...                ...      ...                ...      ...
# 2200          NaN                NaN      NaN                NaN      NaN
# 2202          NaN                NaN      NaN                NaN      NaN
# 2239          NaN                NaN      NaN                NaN      NaN
# 2246          NaN                NaN      NaN                NaN      NaN
# 2250          NaN                NaN      NaN                NaN      NaN
#
#      Sector                   Revenue Competitors                Easy Apply
# 11      NaN  unknown_/_non-applicable         NaN  apply on company website
# 34      NaN                       NaN         NaN  apply on company website
# 55      NaN                       NaN         NaN  apply on company website
# 68      NaN                       NaN         NaN  apply on company website
# 90      NaN                       NaN         NaN  apply on company website
# ...     ...                       ...         ...                       ...
# 2200    NaN                       NaN         NaN  apply on company website
# 2202    NaN                       NaN         NaN  apply on company website
# 2239    NaN                       NaN         NaN  apply on company website
# 2246    NaN                       NaN         NaN  apply on company website
# 2250    NaN                       NaN         NaN  apply on company website
#
# [171 rows x 15 columns]

# %%
df['Headquarters'].fillna(df['Location'],inplace=True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# Headquarters            0
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
df['Size'].value_counts()
# Out:
# 51_to_200_employees        420
# 10000+_employees           375
# 1001_to_5000_employees     348
# 1_to_50_employees          347
# 201_to_500_employees       249
# 501_to_1000_employees      211
# 5001_to_10000_employees     97
# unknown                     42
# Name: Size, dtype: int64

# %%
df['Size'].fillna('Unknown',inplace=True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# Headquarters            0
# Size                    0
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
df['Founded'].to_frame().head()
# Out:
#    Founded
# 0   1961.0
# 1   1893.0
# 2   2003.0
# 3   2002.0
# 4   2009.0

# %%
df['Founded'].mode()[0]
# Out:
# 2008.0

# %%
df['Founded'].fillna(df['Founded'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# Headquarters            0
# Size                    0
# Founded                 0
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
df['Industry'].mode()[0]
# Out:
# 'it_services'

# %%
columns = ['Industry', 'Sector', 'Revenue', 'Competitors','Type of ownership']

for col in columns:
  df[col].fillna(df['Industry'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
top_jobs = df.groupby('Job Title').agg({
    "Easy Apply":"count"
}).reset_index().sort_values('Easy Apply',ascending=False).head(30)

# %%
top_jobs
# Out:
#                                     Job Title  Easy Apply
# 233                              Data Analyst         404
# 996                       Senior Data Analyst          90
# 763                       Junior Data Analyst          30
# 136                     Business Data Analyst          28
# 1156                         Sr. Data Analyst          21
# 364                           Data Analyst II          17
# 375                       Data Analyst Junior          17
# 552                      Data Quality Analyst          17
# 514                   Data Governance Analyst          16
# 774                         Lead Data Analyst          15
# 560                    Data Reporting Analyst          13
# 682                    Financial Data Analyst          12
# 358                            Data Analyst I          11
# 369                          Data Analyst III          11
# 1123                          Sr Data Analyst           9
# 809                    Marketing Data Analyst           9
# 529                   Data Management Analyst           8
# 608                    Data Warehouse Analyst           8
# 1236                   Technical Data Analyst           7
# 948                          SQL Data Analyst           7
# 564                      Data Science Analyst           7
# 579                     Data Security Analyst           6
# 712                   Healthcare Data Analyst           6
# 924                     Research Data Analyst           6
# 183                     Clinical Data Analyst           6
# 834      NY Healthcare Data/Reporting Analyst           5
# 878                      Product Data Analyst           5
# 1073           Senior Healthcare Data Analyst           5
# 370   Data Analyst III (Healthcare Analytics)           5
# 994              Senior Contract Data Analyst           4

# %%
px.bar(top_jobs,x='Job Title',y='Easy Apply')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dc6e122b-d2ed-4ca9-8934-2874ddd1808f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc6e122b-d2ed-4ca9-8934-2874ddd1808f")) {                    Plotly.newPlot(                        "dc6e122b-d2ed-4ca9-8934-2874ddd1808f",                        [{"alignmentgroup":"True","hovertemplate":"Job Title=%{x}<br>Easy Apply=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Data Analyst","Senior Data Analyst","Junior Data Analyst","Business Data Analyst","Sr. Data Analyst","Data Analyst II","Data Analyst Junior","Data Quality Analyst","Data Governance Analyst","Lead Data Analyst","Data Reporting Analyst","Financial Data Analyst","Data Analyst I","Data Analyst III","Sr Data Analyst","Marketing Data Analyst","Data Management Analyst","Data Warehouse Analyst","Technical Data Analyst","SQL Data Analyst","Data Science Analyst","Data Security Analyst","Healthcare Data Analyst","Research Data Analyst","Clinical Data Analyst","NY Healthcare Data/Reporting Analyst","Product Data Analyst","Senior Healthcare Data Analyst","Data Analyst III (Healthcare Analytics)","Senior Contract Data Analyst"],"xaxis":"x","y":[404,90,30,28,21,17,17,17,16,15,13,12,11,11,9,9,8,8,7,7,7,6,6,6,6,5,5,5,5,4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888 ...

# %%
df['Job Title'][0]
# Out:
# 'Data Analyst, Center on Immigration and Justice (CIJ)'

# %%
v = 'Data Analyst, Center on Immigration and Justice (CIJ)'

# %%
v.lower().replace('(','').replace(')','')
# Out:
# 'data analyst, center on immigration and justice cij'

# %%
def clean_job_title(job_title):

    if 'III' in job_title:
        job_title = job_title.replace('III', '')
        job_title = 'lead ' + job_title
    elif 'II' in job_title:
        job_title = job_title.replace('II', '')
        job_title = 'senior ' + job_title
    elif 'I' in job_title:
        job_title = job_title.replace('I', '')
        job_title = 'junior ' + job_title

    job_title = job_title.lower().replace('.', '').replace('sr', 'senior').replace('jr', 'junior').replace('/', ' ')

    if job_title.endswith('junior'):
        job_title = job_title.replace('junior', '')
        job_title = 'junior ' + job_title




    return job_title

# %%
df['Job Title'] = df['Job Title'].apply(clean_job_title)

# %%
df['Job Title'][12]
# Out:
# 'data analyst'

# %%
top_jobs = df.groupby('Job Title').agg({
    "Easy Apply":"count"
}).reset_index().sort_values('Easy Apply',ascending=False).head(30)

# %%
top_jobs
# Out:
#                                       Job Title  Easy Apply
# 154                                data analyst         410
# 1009                        senior data analyst         121
# 607                         junior data analyst          33
# 99                        business data analyst          32
# 608                        junior data analyst           28
# 1010                       senior data analyst           17
# 416                        data quality analyst          17
# 390                     data governance analyst          16
# 801                           lead data analyst          15
# 425                      data reporting analyst          14
# 511                      financial data analyst          12
# 802                          lead data analyst           11
# 840                      marketing data analyst           9
# 467                      data warehouse analyst           8
# 396                     data management analyst           8
# 427                        data science analyst           7
# 1172                           sql data analyst           7
# 1208                     technical data analyst           7
# 1119             senior healthcare data analyst           6
# 940                       research data analyst           6
# 992                senior business data analyst           6
# 532                     healthcare data analyst           6
# 440                       data security analyst           6
# 904                        product data analyst           6
# 125                       clinical data analyst           6
# 870        ny healthcare data reporting analyst           5
# 874                     operations data analyst           5
# 803   lead data analyst  (healthcare analytics)           5
# 634                   junior data analyst ntern           4
# 62                             big data analyst           4

# %%
px.bar(top_jobs,x='Job Title',y='Easy Apply')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1682a2e3-aedd-4fbb-9e7e-c4a7af5e4675" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1682a2e3-aedd-4fbb-9e7e-c4a7af5e4675")) {                    Plotly.newPlot(                        "1682a2e3-aedd-4fbb-9e7e-c4a7af5e4675",                        [{"alignmentgroup":"True","hovertemplate":"Job Title=%{x}<br>Easy Apply=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["data analyst","senior data analyst","junior data analyst","business data analyst","junior data analyst ","senior data analyst ","data quality analyst","data governance analyst","lead data analyst","data reporting analyst","financial data analyst","lead data analyst ","marketing data analyst","data warehouse analyst","data management analyst","data science analyst","sql data analyst","technical data analyst","senior healthcare data analyst","research data analyst","senior business data analyst","healthcare data analyst","data security analyst","product data analyst","clinical data analyst","ny healthcare data reporting analyst","operations data analyst","lead data analyst  (healthcare analytics)","junior data analyst ntern","big data analyst"],"xaxis":"x","y":[410,121,33,32,28,17,17,16,15,14,12,11,9,8,8,7,7,7,6,6,6,6,6,6,6,5,5,5,4,4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777 ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
df['Revenue'].unique()
# Out:
# array(['$100 to $500 million (USD)', '$2 to $5 billion (USD)',
#        'Unknown / Non-Applicable', '$50 to $100 million (USD)',
#        '$1 to $2 billion (USD)', '$5 to $10 billion (USD)',
#        '$1 to $5 million (USD)', '$25 to $50 million (USD)',
#        '$10+ billion (USD)', 'Less than $1 million (USD)',
#        '$10 to $25 million (USD)', 'IT Services',
#        '$500 million to $1 billion (USD)', '$5 to $10 million (USD)'],
#       dtype=object)

# %%
temp = '$42K-$76K (Glassdoor est.)'

# %%
temp.split('-')[1]
# Out:
# '$76K (Glassdoor est.)'

# %%
int(''.join(list(filter(str.isdigit, temp.split('-')[0]))))
# Out:
# 42

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
def get_min_salary(minSalary):
  minSalary = minSalary.lower()
  minSalary = minSalary.split('-')[0]
  minSalary_num = int(''.join(list(filter(str.isdigit,minSalary))))

  if 'k' in minSalary:
    minSalary_num = minSalary_num *1000

  return minSalary_num

# %%
df['min_salary']=df['Salary Estimate'].apply(get_min_salary)

# %%
df['min_salary']
# Out:
# 0       37000
# 1       37000
# 2       37000
# 3       37000
# 4       37000
#         ...
# 2248    78000
# 2249    78000
# 2250    78000
# 2251    78000
# 2252    78000
# Name: min_salary, Length: 2251, dtype: int64

# %%
def max_salary(maxSalary):
  maxSalary = maxSalary.lower()
  maxSalary = maxSalary.split('-')[1]
  maxSalary_Num = int(''.join(list(filter(str.isdigit,maxSalary))))
  if 'k' in maxSalary:
    maxSalary_Num = maxSalary_Num *1000

  return maxSalary_Num

# %%
df['max_salary']=df['Salary Estimate'].apply(max_salary)

# %%
df
# Out:
#                                               Job Title  \
# 0     junior data analyst, center on mmigration and ...
# 1                                  quality data analyst
# 2     junior senior data analyst, nsights & analytic...
# 3                                          data analyst
# 4                                reporting data analyst
# ...                                                 ...
# 2248  junior rqs - hha - 201900004460 -1q data secur...
# 2249              senior data analyst (corporate audit)
# 2250  technical business analyst (sql, data analytic...
# 2251                data analyst 3, customer experience
# 2252                        senior quality data analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...     3.7
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees   1961.0
# 1         New York, NY        10000+ employees   1893.0
# 2         New York, NY  1001 to 5000 employees   2003.0
# 3           McLean, VA    201 to 500 employees   2002.0
# 4         New York, NY   501 to 1000 employees   2009.0
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees   2008.0
# 2249    Centennial, CO        10000+ employees   1935.0
# 2250        Denver, CO                 Unknown   2008.0
# 2251  West Chester, OH    201 to 500 employees   1984.0
# 2252    Broomfield, CO        10000+ employees   1864.0
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                     IT Services                              IT Services
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                       IT Services                 IT Services
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors  \
# 0                                           IT Services
# 1                                           IT Services
# 2                                               GoDaddy
# 3                                           IT Services
# 4                                            DraftKings
# ...                                                 ...
# 2248                                        IT Services
# 2249                     Avnet, Ingram Micro, Tech Data
# 2250                                        IT Services
# 2251                                        IT Services
# 2252  Centura Health, HealthONE, Denver Health and H...
#
#                     Easy Apply  min_salary  max_salary
# 0                         True       37000       66000
# 1     apply on company website       37000       66000
# 2     apply on company website       37000       66000
# 3     apply on company website       37000       66000
# 4                         True       37000       66000
# ...                        ...         ...         ...
# 2248  apply on company website       78000      104000
# 2249  apply on company website       78000      104000
# 2250  apply on company website       78000      104000
# 2251  apply on company website       78000      104000
# 2252  apply on company website       78000      104000
#
# [2251 rows x 17 columns]

# %%
# python, sql, excel, tableau, git, power bi, statistics, mathematics
df['python'] = df['Job Description'].str.contains('python', case=False, na=False)
df['sql'] = df['Job Description'].str.contains('sql', case=False, na=False)
df['excel'] = df['Job Description'].str.contains('excel', case=False, na=False)
df['dash'] = df['Job Description'].str.contains('dash', case=False, na=False)
df['spark'] = df['Job Description'].str.contains('spark', case=False, na=False)
df['tableau'] = df['Job Description'].str.contains('tableau', case=False, na=False)
df['git'] = df['Job Description'].str.contains('git', case=False, na=False)

# %%
df['sql'].value_counts()
# Out:
# True     1387
# False     864
# Name: sql, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'python', 'sql', 'excel',
#        'dash', 'spark', 'tableau', 'git'],
#       dtype='object')

# %% [markdown]
# ## **Count Skilles required in jobs**

# %%
df[['python', 'excel', 'sql','dash', 'spark', 'tableau', 'git']].apply(pd.value_counts)
# Out:
#        python  excel   sql  dash  spark  tableau   git
# False    1614    899   864  1706   2162     1631  1953
# True      637   1352  1387   545     89      620   298

# %% [markdown]
# ## **top 5 jobs market needed**

# %%
df[['Job Title']].apply(pd.value_counts).head().reset_index()
# Out:
#                    index  Job Title
# 0           data analyst        410
# 1    senior data analyst        121
# 2    junior data analyst         33
# 3  business data analyst         32
# 4   junior data analyst          28

# %% [markdown]
# ## **Jobs with skiils required**

# %%
df_ne = df.groupby('Job Title').agg({'python':'sum',
                            'excel':'sum',
                            'sql':'sum',
                            'dash':'sum',
                            'spark':'sum',
                            'tableau':'sum',
                            'git':'sum'}).reset_index().sort_values(by='python',ascending=False).head(5)

# %%
df_ne
# Out:
#                                       Job Title  python  excel  sql  dash  \
# 154                                data analyst     125    240  301   115
# 1009                        senior data analyst      68     66  105    53
# 99                        business data analyst      11     20   25    13
# 801                           lead data analyst       5      7   13     7
# 803   lead data analyst  (healthcare analytics)       5      5    5     3
#
#       spark  tableau  git
# 154      21      110   51
# 1009      7       64   29
# 99        1       12    2
# 801       2       10    3
# 803       0        5    0

# %%
px.bar(df_ne , x= 'Job Title' ,y=['python','excel','sql',	'dash',	'spark',	'tableau'	,'git'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="456b4e63-ee24-4a28-8ce7-46da0824d30c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("456b4e63-ee24-4a28-8ce7-46da0824d30c")) {                    Plotly.newPlot(                        "456b4e63-ee24-4a28-8ce7-46da0824d30c",                        [{"alignmentgroup":"True","hovertemplate":"variable=python<br>Job Title=%{x}<br>value=%{y}<extra></extra>","legendgroup":"python","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"python","offsetgroup":"python","orientation":"v","showlegend":true,"textposition":"auto","x":["data analyst","senior data analyst","business data analyst","lead data analyst","lead data analyst  (healthcare analytics)"],"xaxis":"x","y":[125,68,11,5,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=excel<br>Job Title=%{x}<br>value=%{y}<extra></extra>","legendgroup":"excel","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"excel","offsetgroup":"excel","orientation":"v","showlegend":true,"textposition":"auto","x":["data analyst","senior data analyst","business data analyst","lead data analyst","lead data analyst  (healthcare analytics)"],"xaxis":"x","y":[240,66,20,7,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=sql<br>Job Title=%{x}<br>value=%{y}<extra></extra>","legendgroup":"sql","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"sql","offsetgroup":"sql","orientation":"v","showlegend":true,"textposition":"auto","x":["data analyst","senior data analyst","business data analyst","lead data analyst","lead data analyst  (healthcare analytics)"],"xaxis":"x","y":[301,105,25,13,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=dash<br>Job Title=%{x}<br>value=%{y}<extra></extra>","legendgroup":"dash","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"dash","offsetgroup":"dash","orientation":"v","showlegend":true,"textposition":"auto","x":["data analyst","senior data analyst","business data analyst","lead data analyst","lead data analyst  (healthcare analytics)"],"xaxis":"x","y":[115,53,13,7,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=spark<br>Job Title=%{x}<br>value=%{y}<extra></extra>","legendgroup":"spark","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"spark","offsetgroup":"spark","orientation":"v","showlegend":true,"textposition":"auto","x":["data analyst","senior data analyst","business data analyst","lead data analyst","lead data analyst  (healthcare analytics)"],"xaxis":"x","y":[21,7,1,2,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=tableau<br>Job Title=%{x}<br>value=%{y}<extra></extra>","legendgroup":"tableau","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"tableau","offsetgroup":"tableau","orientation":"v","showlegend":true,"textposition":"auto","x":["data analyst","senior data analyst","business data analyst","lead data analyst","lead data analyst  (healthcare analytics)"],"xaxis":"x","y":[110,64,12,10,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=git<br>Job Title=%{x}<br>value=%{y}<extra></extra>","legendgroup":"git","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"git","offsetgroup":"git","orientation":"v","showlegend":true,"textposition":"auto","x":["data analyst","senior data analyst","business data analyst","lead data analyst","lead data analyst  (healthcare analytics)"],"xaxis":"x","y":[51,29,2,3,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'python', 'sql', 'excel',
#        'dash', 'spark', 'tableau', 'git'],
#       dtype='object')

# %% [markdown]
# ## **Top 10 Fields needed tech included sector**

# %%
df.groupby('Sector').agg({'Job Title':'count'}).reset_index().sort_values(by='Job Title',ascending=False).head()
# Out:
#                     Sector  Job Title
# 12  Information Technology        570
# 4        Business Services        523
# 11             IT Services        352
# 8                  Finance        169
# 10             Health Care        151

# %%
df_pie_sec =df['Sector'].value_counts().to_frame().reset_index().head(10)

# %%
px.pie(df_pie_sec, values='Sector', names='index')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="08944880-ece6-4f46-ac6f-0516b2281423" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08944880-ece6-4f46-ac6f-0516b2281423")) {                    Plotly.newPlot(                        "08944880-ece6-4f46-ac6f-0516b2281423",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>Sector=%{value}<extra></extra>","labels":["Information Technology","Business Services","IT Services","Finance","Health Care","Education","Insurance","Accounting & Legal","Media","Manufacturing"],"legendgroup":"","name":"","showlegend":true,"values":[570,523,352,169,151,52,51,43,42,40],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatte ...

# %% [markdown]
# ## **Top 10 Fields needed tech included industry**

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'python', 'sql', 'excel',
#        'dash', 'spark', 'tableau', 'git'],
#       dtype='object')

# %%
df_pie_ind = df['Industry'].value_counts().to_frame().reset_index().head(10)

# %%
px.pie(df_pie_ind, values='Industry',names='index')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="60c431f6-b4ac-4f3a-a75c-2e401e961f7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60c431f6-b4ac-4f3a-a75c-2e401e961f7e")) {                    Plotly.newPlot(                        "60c431f6-b4ac-4f3a-a75c-2e401e961f7e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>Industry=%{value}<extra></extra>","labels":["IT Services","Staffing & Outsourcing","Health Care Services & Hospitals","Computer Hardware & Software","Consulting","Investment Banking & Asset Management","Enterprise Software & Network Solutions","Internet","Advertising & Marketing","Banks & Credit Unions"],"legendgroup":"","name":"","showlegend":true,"values":[677,322,151,111,111,78,69,65,51,51],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{ ...

# %% [markdown]
# ## **Relation Between revenue and average salary**

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'python', 'sql', 'excel',
#        'dash', 'spark', 'tableau', 'git'],
#       dtype='object')

# %%
# The salary for each player's age with the prefered foot
px.histogram(df, x='Revenue',y='min_salary')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="527fac03-02c1-4d5c-9413-fa42c25ca003" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("527fac03-02c1-4d5c-9413-fa42c25ca003")) {                    Plotly.newPlot(                        "527fac03-02c1-4d5c-9413-fa42c25ca003",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Revenue=%{x}<br>sum of min_salary=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["$100 to $500 million (USD)","$2 to $5 billion (USD)","Unknown / Non-Applicable","$50 to $100 million (USD)","$100 to $500 million (USD)","Unknown / Non-Applicable","Unknown / Non-Applicable","$100 to $500 million (USD)","$1 to $2 billion (USD)","Unknown / Non-Applicable","$5 to $10 billion (USD)","Unknown / Non-Applicable","$2 to $5 billion (USD)","$100 to $500 million (USD)","$1 to $5 million (USD)","Unknown / Non-Applicable","Unknown / Non-Applicable","$25 to $50 million (USD)","$100 to $500 million (USD)","Unknown / Non-Applicable","$10+ billion (USD)","Unknown / Non-Applicable","$5 to $10 billion (USD)","$1 to $5 million (USD)","Unknown / Non-Applicable","Less than $1 million (USD)","$10 to $25 million (USD)","Unknown / Non-Applicable","$1 to $5 million (USD)","Unknown / Non-Applicable","$25 to $50 million (USD)","$1 to $5 million (USD)","Less than $1 million (USD)","Unknown / Non-Applicable","IT Services","$10+ billion (USD)","$1 to $5 million (USD)","Less than $1 million (USD)","$5 to $10 billion (USD)","$10 to $25 million (USD)","Unknown / Non-Applicable","Unknown / Non-Applicable","Unknown / Non-Applicable","$1 to $5 million (USD)","Unknown / Non-Applicable","$500 million to $1 billion (USD)","Less than $1 million (USD)","$100 to $500 million (USD)","Unknown / Non-Applicable","$500 million to $1 billion (USD)","$10+ billion (USD)","$50 to $100 million (USD)","$100 to $500 million (USD)","Unknown / Non-Applicable","$50 to $100 million (USD)","IT Services","$10+ billion (USD)","$500 million to $1 billion (USD)","Unknown / Non-Applicable","$25 to $50 million (USD)","Unknown / Non-Applicable","$500 million to $1 billion (USD)","$500 million to $1 billion (USD)","$500 million to $1 billion (USD)","$1 to $2 billion (USD)","$2 to $5 billion (USD)","$1 to $5 million (USD)","$500 million to $1 billion (USD)","IT Services","$100 to $500 million (USD)","$50 to $100 million (USD)","Unknown / Non-Applicable","Unknown / Non-Applicable","$10+ billion (USD)","$100 to $500 million (USD)","Unknown / Non-Applicable","$5 to $10 billion (USD)","Unknown / Non-Applicable","Unknown / Non-Applicable","$1 to $5 million (USD)","Unknown / Non-Applicable","Unknown / Non-Applicable","Unknown / Non-Applicable","$100 to $500 million (USD)","Less than $1 million (USD)","Unknown / Non-Applicable","Less than $1 million (USD)","$10 to $25 million (USD)","Unknown / Non-Applicable","$500 million to $1 billion (USD)","IT Services","$2 to $5 billion (USD)","$500 million to $1 billion (USD)","$10 to $25 million (USD)","$2 to $5 billion (USD)","$1 to $5 million (USD)","Unknown / Non-Applicable","Unknown / Non-Applicable","Unknown / Non-Applicable","$10 to $25 million (USD)","Unknown / Non-Applicable","$10 to $25 million (USD)","$1 to $2 billion (USD)","$10+ billion (USD)","$25 to $50 million (USD)","Unknown / Non-Applicable","$5 to $10 million (USD)","$50 to $100 million (USD)","Unknown / Non-Applicable","IT Services","Unknown / Non-Applicable","$100 to $500 million (USD)","$2 to $5 billion (USD)","$25 to $50 million (USD)","Unknown / Non-Applicable","$10+ billion (USD)","$100 to $500 million (USD)","$5 to $10 million (USD)","Unknown / Non-Applicable","$100 to  ...

# %%
import re

# %%
def reven_handel(value):

  value = value.lower()

  if 'unknown' in value:
    return np.nan

  elif 'to' in value:
    # calculate average

    lower_val,upper_val = value.split('to')

    min_val = int(re.findall(r'\d+', lower_val)[0])
    max_val = int(re.findall(r'\d+', upper_val)[0])

    if 'billion' in lower_val:
      min_val = min_val*1000
    if 'billion' in upper_val:
      max_val = max_val*1000

    average_rev = int((min_val + max_val) / 2)

    return average_rev

  elif ('less' in value) or ('+' in value):
    number = int(re.findall(r'\d+', value)[0])

    if 'billion' in value:
      number*=10**3
    return number

# %%
df['Revenue_cleaned']=df['Revenue'].apply(reven_handel)

# %%
df['Revenue_cleaned']
# Out:
# 0         300.0
# 1        2501.0
# 2           NaN
# 3          75.0
# 4         300.0
#          ...
# 2248        NaN
# 2249    10000.0
# 2250        NaN
# 2251       37.0
# 2252     2501.0
# Name: Revenue_cleaned, Length: 2251, dtype: float64

# %%
px.histogram(df, x='Revenue_cleaned',y='min_salary')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ed8698ed-a276-425e-b4ae-2f58fcdb3105" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed8698ed-a276-425e-b4ae-2f58fcdb3105")) {                    Plotly.newPlot(                        "ed8698ed-a276-425e-b4ae-2f58fcdb3105",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Revenue_cleaned=%{x}<br>sum of min_salary=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[300.0,2501.0,null,75.0,300.0,null,null,300.0,1000.0,null,5002.0,null,2501.0,300.0,3.0,null,null,37.0,300.0,null,10000.0,null,5002.0,3.0,null,1.0,17.0,null,3.0,null,37.0,3.0,1.0,null,null,10000.0,3.0,1.0,5002.0,17.0,null,null,null,3.0,null,750.0,1.0,300.0,null,750.0,10000.0,75.0,300.0,null,75.0,null,10000.0,750.0,null,37.0,null,750.0,750.0,750.0,1000.0,2501.0,3.0,750.0,null,300.0,75.0,null,null,10000.0,300.0,null,5002.0,null,null,3.0,null,null,null,300.0,1.0,null,1.0,17.0,null,750.0,null,2501.0,750.0,17.0,2501.0,3.0,null,null,null,17.0,null,17.0,1000.0,10000.0,37.0,null,7.0,75.0,null,null,null,300.0,2501.0,37.0,null,10000.0,300.0,7.0,null,300.0,null,10000.0,3.0,null,75.0,10000.0,10000.0,37.0,null,10000.0,37.0,3.0,null,75.0,7.0,2501.0,17.0,3.0,300.0,null,null,2501.0,17.0,null,300.0,3.0,7.0,10000.0,null,null,5002.0,null,1000.0,null,17.0,37.0,17.0,null,1000.0,37.0,17.0,null,null,null,17.0,17.0,null,null,300.0,37.0,3.0,300.0,17.0,10000.0,null,75.0,75.0,10000.0,null,null,750.0,1.0,null,null,37.0,17.0,null,75.0,10000.0,37.0,75.0,10000.0,1000.0,17.0,null,10000.0,null,750.0,300.0,null,2501.0,1.0,3.0,null,3.0,null,3.0,null,3.0,17.0,1.0,75.0,null,null,37.0,300.0,null,3.0,10000.0,10000.0,10000.0,75.0,null,17.0,37.0,null,7.0,null,2501.0,17.0,null,null,300.0,37.0,null,300.0,null,750.0,1.0,10000.0,10000.0,75.0,null,2501.0,null,750.0,10000.0,null,2501.0,10000.0,300.0,10000.0,null,null,750.0,null,10000.0,750.0,null,null,3.0,17.0,37.0,null,75.0,1.0,1.0,null,300.0,7.0,1000.0,null,null,300.0,300.0,null,null,10000.0,null,null,1000.0,null,37.0,null,null,75.0,750.0,10000.0,5002.0,3.0,10000.0,null,300.0,75.0,75.0,300.0,1000.0,2501.0,10000.0,750.0,10000.0,null,10000.0,300.0,75.0,17.0,37.0,7.0,null,2501.0,750.0,null,37.0,null,75.0,null,null,10000.0,17.0,300.0,750.0,300.0,null,17.0,300.0,null,2501.0,null,null,10000.0,1.0,5002.0,75.0,75.0,null,75.0,37.0,null,10000.0,75.0,2501.0,5002.0,null,null,null,5002.0,75.0,3.0,3.0,75.0,null,2501.0,300.0,5002.0,3.0,null,null,null,5002.0,7.0,2501.0,37.0,10000.0,7.0,null,5002.0,1.0,null,10000.0,null,75.0,5002.0,10000.0,17.0,1000.0,75.0,null,75.0,10000.0,2501.0,75.0,1.0,null,null,null,null,3.0,10000.0,null,75.0,null,null,null,300.0,3.0,17.0,null,1000.0,75.0,7.0,10000.0,null,null,null,null,1.0,10000.0,17.0,null,75.0,10000.0,10000.0,1000.0,null,null,17.0,75.0,null,null,null,null,null,7.0,2501.0,300.0,3.0,null,75.0,null,null,37.0,10000.0,null,37.0,75.0,1.0,300.0,7.0,300.0,null,null,1000.0,300.0,17.0,null,null,null,75.0,7.0,null,37.0,75.0,7.0,null,2501.0,3.0,75.0,75.0,300.0,37.0,75.0,75.0,17.0,1.0,3.0,7.0,75.0,17.0,null,10000.0,5002.0,null,300.0,300.0,null,75.0,17.0,300.0,17.0,null,7.0,300.0,17.0,7.0,17.0,17.0,17.0,300.0,null,17.0,3.0,null,17.0,null,17.0,null,null,300.0,2501.0,null,null,300.0,null,37.0,37.0,75.0,75.0,1000.0,750.0,750.0,75.0,75.0,750.0,300.0,null,750.0,3.0,null,75.0,null,3.0,null,75.0,null,17.0,37.0,null,null,1.0,null,300.0,1.0,null,7.0,2501.0,null,2501.0,null,null,null,null,null,null,null,2501.0,17.0,7.0,7.0,2501.0,null,null,null,1000.0,7.0,2501.0,75.0,null,10000.0,null,17.0,2501.0,2501.0,1000.0,10000.0,1000.0,null,2501.0,75.0,null,2501.0,75.0,17.0,null,17.0,2501.0,null,null,null,null,null,null,null,3 ...

# %%
def reven_handel(value):

  if 'unknown' in value:
    return np.nan

  if 'to' in value:

    lower_val,upper_val = value.split('to')

    min_val = int(re.findall(r'\d+', lower_val)[0])* 10**3
    max_val = int(re.findall(r'\d+', upper_val)[0])* 10**3

    average_rev = int((min_val + max_val) / 2)
    print(average_rev)

# %%
df['Revenue'][0].lower().split('to')
# Out:
# ['$100 ', ' $500 million (usd)']

# %%
df['Revenue'][1].lower().split('to')
# Out:
# ['$2 ', ' $5 billion (usd)']

# %%
df['Revenue'][2].lower().split('to')
# Out:
# ['unknown / non-applicable']

# %%
df['Revenue'][3].lower().split('to')
# Out:
# ['$50 ', ' $100 million (usd)']
