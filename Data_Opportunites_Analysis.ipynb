# %% [markdown]
# <a href="https://colab.research.google.com/github/MINAADELMARKOS/Data_Opportunites_Analysis/blob/main/Data_Opportunites_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Imoort Libraries**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.figure_factory as ff
import plotly.io as pio
import plotly.graph_objects as go

# %%
import plotly.io as pio
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly_white'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
pio.templates.default = 'plotly_white'

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Epslion Project before midproject/Data Analyst Project/DataAnalyst.csv')

# %% [markdown]
# # **Explatory Data Analyst**

# %%
df.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
df.columns[0]
# Out:
# 'Unnamed: 0'

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# ...

# %%
# @title sql

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('sql').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
str_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in str_columns:
  df[col] = df[col].str.lower().str.replace(' ','_')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  data_analyst,_center_on_immigration_and_justic...
# 1                               quality_data_analyst
# 2  senior_data_analyst,_insights_&_analytics_team...
# 3                                       data_analyst
# 4                             reporting_data_analyst
#
#               Salary Estimate  \
# 0  $37k-$66k_(glassdoor_est.)
# 1  $37k-$66k_(glassdoor_est.)
# 2  $37k-$66k_(glassdoor_est.)
# 3  $37k-$66k_(glassdoor_est.)
# 4  $37k-$66k_(glassdoor_est.)
#
#                                      Job Description  Rating  \
# 0  are_you_eager_to_roll_up_your_sleeves_and_harn...     3.2
# 1  overview\n\nprovides_analytical_and_technical_...     3.8
# 2  we’re_looking_for_a_senior_data_analyst_who_ha...     3.4
# 3  requisition_numberrr-0001939\nremote:yes\nwe_c...     4.1
# 4  about_fanduel_group\n\nfanduel_group_is_a_worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# ...

# %%
# @title min_salary vs max_salary

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='min_salary', y='max_salary', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2253 non-null   object
#  1   Salary Estimate    2253 non-null   object
#  2   Job Description    2253 non-null   object
#  3   Rating             2253 non-null   float64
#  4   Company Name       2252 non-null   object
#  5   Location           2253 non-null   object
#  6   Headquarters       2253 non-null   object
#  7   Size               2253 non-null   object
#  8   Founded            2253 non-null   int64
#  9   Type of ownership  2253 non-null   object
#  10  Industry           2253 non-null   object
#  11  Sector             2253 non-null   object
#  12  Revenue            2253 non-null   object
#  13  Competitors        2253 non-null   object
#  14  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(1), object(13)
# ...

# %%
df.isna().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
df.describe()
# Out:
#             Rating      Founded
# count  2253.000000  2253.000000
# mean      3.160630  1398.522858
# std       1.665228   901.929251
# min      -1.000000    -1.000000
# 25%       3.100000    -1.000000
# 50%       3.600000  1979.000000
# 75%       4.000000  2002.000000
# max       5.000000  2019.000000

# %%
df.replace(-1,np.nan,inplace=True)

# %%
df.describe()
# Out:
#             Rating      Founded
# count  1981.000000  1593.000000
# mean      3.731903  1978.362837
# std       0.670332    47.822289
# min       1.000000  1682.000000
# 25%       3.300000  1970.000000
# 50%       3.700000  1997.000000
# 75%       4.100000  2006.000000
# max       5.000000  2019.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Founded'].plot(kind='hist', bins=20, title='Founded')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
_df_4['Founded'].plot(kind='line', figsize=(8, 4), title='Founded')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.isna().sum()
# Out:
# Job Title              0
# Salary Estimate        0
# Job Description        0
# Rating               272
# Company Name           1
# Location               0
# Headquarters           0
# Size                   0
# Founded              660
# Type of ownership      0
# Industry               0
# Sector                 0
# Revenue                0
# Competitors            0
# Easy Apply             0
# dtype: int64

# %%
df.describe(include='O')
# Out:
#            Job Title             Salary Estimate  \
# count           2253                        2253
# unique          1257                          90
# top     data_analyst  $42k-$76k_(glassdoor_est.)
# freq             411                          57
#
#                                           Job Description  \
# count                                                2253
# unique                                               2252
# top     job_description\ninterpret_data,_analyze_resul...
# freq                                                    2
#
#                                  Company Name      Location  Headquarters  \
# count                                    2252          2253          2253
# unique                                   1511           253           483
# top     staffigo_technical_services,_llc\n5.0  new_york,_ny  new_york,_ny
# freq                                       58           310           206
#
# ...

# %%
df.replace('-1',np.nan,inplace=True)

# %%
df.describe(include='O')
# Out:
#            Job Title             Salary Estimate  \
# count           2253                        2252
# unique          1257                          89
# top     data_analyst  $42k-$76k_(glassdoor_est.)
# freq             411                          57
#
#                                           Job Description  \
# count                                                2253
# unique                                               2252
# top     job_description\ninterpret_data,_analyze_resul...
# freq                                                    2
#
#                                  Company Name      Location  Headquarters  \
# count                                    2252          2253          2081
# unique                                   1511           253           482
# top     staffigo_technical_services,_llc\n5.0  new_york,_ny  new_york,_ny
# freq                                       58           310           206
#
# ...

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         1
# Job Description         0
# Rating                272
# Company Name            1
# Location                0
# Headquarters          172
# Size                  163
# Founded               660
# Type of ownership     163
# Industry              353
# Sector                353
# Revenue               163
# Competitors          1732
# Easy Apply           2173
# dtype: int64

# %% [markdown]
# # **Handeling Missing Data**

# %%
df['Easy Apply'].to_frame().head(6)
# Out:
#   Easy Apply
# 0       true
# 1        NaN
# 2        NaN
# 3        NaN
# 4       true
# 5        NaN
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('Easy Apply').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_5.groupby('Easy Apply').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['Easy Apply'].replace(np.nan,"apply on company website",inplace=True)

# %%
df['Easy Apply'].to_frame().head(6)
# Out:
#                  Easy Apply
# 0                      true
# 1  apply on company website
# 2  apply on company website
# 3  apply on company website
# 4                      true
# 5  apply on company website

# %%
df['Easy Apply'].value_counts()
# Out:
# Easy Apply
# apply on company website    2173
# true                          80
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         1
# Job Description         0
# Rating                272
# Company Name            1
# Location                0
# Headquarters          172
# Size                  163
# Founded               660
# Type of ownership     163
# Industry              353
# Sector                353
# Revenue               163
# Competitors          1732
# Easy Apply              0
# dtype: int64

# %%
df.dropna(subset=['Salary Estimate','Company Name'],inplace = True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                271
# Company Name            0
# Location                0
# Headquarters          171
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
px.histogram(df,x='Rating')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(df,x='Rating',template ='simple_white')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df ,x='Founded' ,y='Rating' , marginal_y="histogram",template ='simple_white')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.imshow(df.corr().round(2), text_auto=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-e8f304f236ad> in <cell line: 1>()
# ----> 1 px.imshow(df.corr().round(2), text_auto=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                271
# Company Name            0
# Location                0
# Headquarters          171
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
df['Rating'].median()
# Out:
# 3.7

# %%
df['Rating'].fillna(df['Rating'].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# Headquarters          171
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
pd.pivot_table(df, values='Job Title', index=['Salary Estimate'],
                    columns=['Size'], aggfunc='count', fill_value=0)
# Out:
# Size                          10000+_employees  1001_to_5000_employees  \
# Salary Estimate
# $110k-$190k_(glassdoor_est.)                 3                       7
# $113k-$132k_(glassdoor_est.)                 4                       4
# $24k-$48k_(glassdoor_est.)                   7                       6
# $26k-$47k_(glassdoor_est.)                   3                       2
# $27k-$52k_(glassdoor_est.)                   9                       4
# ...                                        ...                     ...
# $89k-$151k_(glassdoor_est.)                  5                       4
# $93k-$159k_(glassdoor_est.)                  2                       5
# $97k-$129k_(glassdoor_est.)                  6                       3
# $98k-$114k_(glassdoor_est.)                  5                       3
# $99k-$178k_(glassdoor_est.)                  3                       4
#
# Size                          1_to_50_employees  201_to_500_employees  \
# Salary Estimate
# ...

# %%
df[df['Headquarters'].isna()]
# Out:
#                                               Job Title  \
# 11                                         data_analyst
# 34                                 data_analyst_(games)
# 55                               data_reporting_analyst
# 68                                 data_science_analyst
# 90                                         data_analyst
# ...                                                 ...
# 2200                                       data_analyst
# 2202                             financial_data_analyst
# 2239                       senior_contract_data_analyst
# 2246  technical_business_analyst_(sql,_data_analytic...
# 2250  technical_business_analyst_(sql,_data_analytic...
#
#                   Salary Estimate  \
# 11     $37k-$66k_(glassdoor_est.)
# 34     $46k-$87k_(glassdoor_est.)
# 55     $46k-$87k_(glassdoor_est.)
# 68     $51k-$88k_(glassdoor_est.)
# 90     $51k-$87k_(glassdoor_est.)
# ...                           ...
# 2200   $49k-$91k_(glassdoor_est.)
# ...

# %%
df['Headquarters'].fillna(df['Location'],inplace=True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# Headquarters            0
# Size                  162
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
df['Size'].value_counts()
# Out:
# Size
# 51_to_200_employees        420
# 10000+_employees           375
# 1001_to_5000_employees     348
# 1_to_50_employees          347
# 201_to_500_employees       249
# 501_to_1000_employees      211
# 5001_to_10000_employees     97
# unknown                     42
# Name: count, dtype: int64

# %%
df['Size'].fillna('Unknown',inplace=True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# Headquarters            0
# Size                    0
# Founded               659
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
df['Founded'].to_frame().head()
# Out:
#    Founded
# 0   1961.0
# 1   1893.0
# 2   2003.0
# 3   2002.0
# 4   2009.0

# %%
df['Founded'].mode()[0]
# Out:
# 2008.0

# %%
df['Founded'].fillna(df['Founded'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# Headquarters            0
# Size                    0
# Founded                 0
# Type of ownership     162
# Industry              352
# Sector                352
# Revenue               162
# Competitors          1730
# Easy Apply              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
df['Industry'].mode()[0]
# Out:
# 'it_services'

# %%
columns = ['Industry', 'Sector', 'Revenue', 'Competitors','Type of ownership']

for col in columns:
  df[col].fillna(df['Industry'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
top_jobs = df.groupby('Job Title').agg({
    "Easy Apply":"count"
}).reset_index().sort_values('Easy Apply',ascending=False).head(30)

# %%
top_jobs
# Out:
#                                     Job Title  Easy Apply
# 228                              data_analyst         410
# 977                       senior_data_analyst          92
# 758                       junior_data_analyst          30
# 138                     business_data_analyst          28
# 1120                         sr._data_analyst          21
# 433                           data_analyst_ii          17
# 559                      data_quality_analyst          17
# 444                       data_analyst_junior          17
# 520                   data_governance_analyst          16
# 768                         lead_data_analyst          15
# 567                    data_reporting_analyst          13
# 678                    financial_data_analyst          12
# 438                          data_analyst_iii          11
# 427                            data_analyst_i          11
# 1169                          sr_data_analyst           9
# ...

# %%
px.bar(top_jobs,x='Job Title',y='Easy Apply')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Job Title'][0]
# Out:
# 'data_analyst,_center_on_immigration_and_justice_(cij)'

# %%
v = 'Data Analyst, Center on Immigration and Justice (CIJ)'

# %%
v.lower().replace('(','').replace(')','')
# Out:
# 'data analyst, center on immigration and justice cij'

# %%
def clean_job_title(job_title):

    if 'III' in job_title:
        job_title = job_title.replace('III', '')
        job_title = 'lead ' + job_title
    elif 'II' in job_title:
        job_title = job_title.replace('II', '')
        job_title = 'senior ' + job_title
    elif 'I' in job_title:
        job_title = job_title.replace('I', '')
        job_title = 'junior ' + job_title

    job_title = job_title.lower().replace('.', '').replace('sr', 'senior').replace('jr', 'junior').replace('/', ' ')

    if job_title.endswith('junior'):
        job_title = job_title.replace('junior', '')
        job_title = 'junior ' + job_title




    return job_title

# %%
df['Job Title'] = df['Job Title'].apply(clean_job_title)

# %%
df['Job Title'][12]
# Out:
# 'data_analyst'

# %%
top_jobs = df.groupby('Job Title').agg({
    "Easy Apply":"count"
}).reset_index().sort_values('Easy Apply',ascending=False).head(30)

# %%
top_jobs
# Out:
#                                     Job Title  Easy Apply
# 225                              data_analyst         410
# 997                       senior_data_analyst         122
# 749                       junior_data_analyst          33
# 136                     business_data_analyst          28
# 428                           data_analyst_ii          17
# 744                      junior data_analyst_          17
# 552                      data_quality_analyst          17
# 513                   data_governance_analyst          16
# 764                         lead_data_analyst          15
# 560                    data_reporting_analyst          13
# 671                    financial_data_analyst          12
# 422                            data_analyst_i          11
# 433                          data_analyst_iii          11
# 796                    marketing_data_analyst           9
# 176                     clinical_data_analyst           8
# ...

# %%
px.bar(top_jobs,x='Job Title',y='Easy Apply')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
df['Revenue'].unique()
# Out:
# array(['$100_to_$500_million_(usd)', '$2_to_$5_billion_(usd)',
#        'unknown_/_non-applicable', '$50_to_$100_million_(usd)',
#        '$1_to_$2_billion_(usd)', '$5_to_$10_billion_(usd)',
#        '$1_to_$5_million_(usd)', '$25_to_$50_million_(usd)',
#        '$10+_billion_(usd)', 'less_than_$1_million_(usd)',
#        '$10_to_$25_million_(usd)', 'it_services',
#        '$500_million_to_$1_billion_(usd)', '$5_to_$10_million_(usd)'],
#       dtype=object)

# %%
temp = '$42K-$76K (Glassdoor est.)'

# %%
temp.split('-')[1]
# Out:
# '$76K (Glassdoor est.)'

# %%
int(''.join(list(filter(str.isdigit, temp.split('-')[0]))))
# Out:
# 42

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
def get_min_salary(minSalary):
  minSalary = minSalary.lower()
  minSalary = minSalary.split('-')[0]
  minSalary_num = int(''.join(list(filter(str.isdigit,minSalary))))

  if 'k' in minSalary:
    minSalary_num = minSalary_num *1000

  return minSalary_num

# %%
df['min_salary']=df['Salary Estimate'].apply(get_min_salary)

# %%
df['min_salary']
# Out:
# 0       37000
# 1       37000
# 2       37000
# 3       37000
# 4       37000
#         ...
# 2248    78000
# 2249    78000
# 2250    78000
# 2251    78000
# 2252    78000
# Name: min_salary, Length: 2251, dtype: int64

# %%
def max_salary(maxSalary):
  maxSalary = maxSalary.lower()
  maxSalary = maxSalary.split('-')[1]
  maxSalary_Num = int(''.join(list(filter(str.isdigit,maxSalary))))
  if 'k' in maxSalary:
    maxSalary_Num = maxSalary_Num *1000

  return maxSalary_Num

# %%
df['max_salary']=df['Salary Estimate'].apply(max_salary)

# %%
df
# Out:
#                                               Job Title  \
# 0     data_analyst,_center_on_immigration_and_justic...
# 1                                  quality_data_analyst
# 2     senior_data_analyst,_insights_&_analytics_team...
# 3                                          data_analyst
# 4                                reporting_data_analyst
# ...                                                 ...
# 2248  rqs_-_ihha_-_201900004460_-1q_data_security_an...
# 2249              senior_data_analyst_(corporate_audit)
# 2250  technical_business_analyst_(sql,_data_analytic...
# 2251                data_analyst_3,_customer_experience
# 2252                        senior_quality_data_analyst
#
#                   Salary Estimate  \
# 0      $37k-$66k_(glassdoor_est.)
# 1      $37k-$66k_(glassdoor_est.)
# 2      $37k-$66k_(glassdoor_est.)
# 3      $37k-$66k_(glassdoor_est.)
# 4      $37k-$66k_(glassdoor_est.)
# ...                           ...
# 2248  $78k-$104k_(glassdoor_est.)
# ...

# %%
# python, sql, excel, tableau, git, power bi, statistics, mathematics
df['python'] = df['Job Description'].str.contains('python', case=False, na=False)
df['sql'] = df['Job Description'].str.contains('sql', case=False, na=False)
df['excel'] = df['Job Description'].str.contains('excel', case=False, na=False)
df['dash'] = df['Job Description'].str.contains('dash', case=False, na=False)
df['spark'] = df['Job Description'].str.contains('spark', case=False, na=False)
df['tableau'] = df['Job Description'].str.contains('tableau', case=False, na=False)
df['git'] = df['Job Description'].str.contains('git', case=False, na=False)

# %%
df['sql'].value_counts()
# Out:
# sql
# True     1387
# False     864
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'python', 'sql', 'excel',
#        'dash', 'spark', 'tableau', 'git'],
#       dtype='object')

# %% [markdown]
# ## **Count Skilles required in jobs**

# %%
df[['python', 'excel', 'sql','dash', 'spark', 'tableau', 'git']].apply(pd.value_counts)
# Out:
#        python  excel   sql  dash  spark  tableau   git
# False    1614    899   864  1706   2162     1631  1953
# True      637   1352  1387   545     89      620   298

# %% [markdown]
# ## **top 5 jobs market needed**

# %%
df['Job Title_counts'] = df[['Job Title']].apply(pd.value_counts)
df[['Job Title', 'Job Title_counts']].head()
# Out:
#                                            Job Title  Job Title_counts
# 0  data_analyst,_center_on_immigration_and_justic...               NaN
# 1                               quality_data_analyst               NaN
# 2  senior_data_analyst,_insights_&_analytics_team...               NaN
# 3                                       data_analyst               NaN
# 4                             reporting_data_analyst               NaN

# %% [markdown]
# ## **Jobs with skiils required**

# %%
df_ne = df.groupby('Job Title').agg({'python':'sum',
                            'excel':'sum',
                            'sql':'sum',
                            'dash':'sum',
                            'spark':'sum',
                            'tableau':'sum',
                            'git':'sum'}).reset_index().sort_values(by='python',ascending=False).head(5)

# %%
df_ne
# Out:
#                                    Job Title  python  excel  sql  dash  spark  \
# 225                             data_analyst     125    240  301   115     21
# 997                      senior_data_analyst      68     66  105    53      7
# 136                    business_data_analyst      11     17   21    10      1
# 764                        lead_data_analyst       5      7   13     7      2
# 435  data_analyst_iii_(healthcare_analytics)       5      5    5     3      0
#
#      tableau  git
# 225      110   51
# 997       64   29
# 136       11    2
# 764       10    3
# 435        5    0

# %%
px.bar(df_ne , x= 'Job Title' ,y=['python','excel','sql',	'dash',	'spark',	'tableau'	,'git'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'python', 'sql', 'excel',
#        'dash', 'spark', 'tableau', 'git'],
#       dtype='object')

# %% [markdown]
# ## **Top 10 Fields needed tech included sector**

# %%
df.groupby('Sector').agg({'Job Title':'count'}).reset_index().sort_values(by='Job Title',ascending=False).head()
# Out:
#                     Sector  Job Title
# 11  information_technology        570
# 4        business_services        523
# 13             it_services        352
# 8                  finance        169
# 10             health_care        151

# %%
df_pie_sec =df['Sector'].value_counts().to_frame().reset_index().head(10)

# %%
# Change the 'names' argument to 'Sector'
px.pie(df_pie_sec, values='Sector', names='Sector')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Top 10 Fields needed tech included industry**

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'python', 'sql', 'excel',
#        'dash', 'spark', 'tableau', 'git', 'Job Title_counts'],
#       dtype='object')

# %%
df_pie_ind = df['Industry'].value_counts().to_frame().reset_index().head(10)

# %%
px.pie(df_pie_ind, values='Industry', names='Industry')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Relation Between revenue and average salary**

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'min_salary', 'max_salary', 'python', 'sql', 'excel',
#        'dash', 'spark', 'tableau', 'git', 'Job Title_counts'],
#       dtype='object')

# %%
# The salary for each player's age with the prefered foot
px.histogram(df, x='Revenue',y='min_salary').show("png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-aaaa2a6370c8> in <cell line: 2>()
#       1 # The salary for each player's age with the prefered foot
# ----> 2 px.histogram(df, x='Revenue',y='min_salary').show("png")
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in show(self, *args, **kwargs)
#    3407         import plotly.io as pio
#    3408
# -> 3409         return pio.show(self, *args, **kwargs)
#    3410
#    3411     def to_json(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     386
#     387     # Mimetype renderers
# --> 388     bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     389     if bundle:
#     390         if not ipython_display:
#
# ...

# %%
import re

# %%
def reven_handel(value):

  value = value.lower()

  if 'unknown' in value:
    return np.nan

  elif 'to' in value:
    # calculate average

    lower_val,upper_val = value.split('to')

    min_val = int(re.findall(r'\d+', lower_val)[0])
    max_val = int(re.findall(r'\d+', upper_val)[0])

    if 'billion' in lower_val:
      min_val = min_val*1000
    if 'billion' in upper_val:
      max_val = max_val*1000

    average_rev = int((min_val + max_val) / 2)

    return average_rev

  elif ('less' in value) or ('+' in value):
    number = int(re.findall(r'\d+', value)[0])

    if 'billion' in value:
      number*=10**3
    return number

# %%
df['Revenue_cleaned']=df['Revenue'].apply(reven_handel)

# %%
df['Revenue_cleaned']
# Out:
# 0         300.0
# 1        2501.0
# 2           NaN
# 3          75.0
# 4         300.0
#          ...
# 2248        NaN
# 2249    10000.0
# 2250        NaN
# 2251       37.0
# 2252     2501.0
# Name: Revenue_cleaned, Length: 2251, dtype: float64

# %%
px.histogram(df, x='Revenue_cleaned',y='min_salary')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def reven_handel(value):

  if 'unknown' in value:
    return np.nan

  if 'to' in value:

    lower_val,upper_val = value.split('to')

    min_val = int(re.findall(r'\d+', lower_val)[0])* 10**3
    max_val = int(re.findall(r'\d+', upper_val)[0])* 10**3

    average_rev = int((min_val + max_val) / 2)
    print(average_rev)

# %%
df['Revenue'][0].lower().split('to')
# Out:
# ['$100_', '_$500_million_(usd)']

# %%
df['Revenue'][1].lower().split('to')
# Out:
# ['$2_', '_$5_billion_(usd)']

# %%
df['Revenue'][2].lower().split('to')
# Out:
# ['unknown_/_non-applicable']

# %%
df['Revenue'][3].lower().split('to')
# Out:
# ['$50_', '_$100_million_(usd)']
